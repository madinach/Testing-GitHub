# %%
def math_function(a):
    b= 2+3*a
    c= b-20
    d= a*c
    
    return(a,b)

def printing(d):
    print(f'Hi there! you printed {d}. Well done!')
    return

printing("ff")
math_function(4)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-6-36130a7b38a8> in <module>
#      10     return
#      11
# ---> 12 printing("ff")
#
# <ipython-input-6-36130a7b38a8> in printing(d)
#       7
#       8 def printing(d):
# ----> 9     print(f'Hi there! you printed {d}. Well done!')
#      10     return
#      11
#
# <ipython-input-3-ce05055c122e> in print(d)
#       7
#       8 def print(d):
# ----> 9     print(f'Hi there! you printed {d}. Well done!')
#      10     return
#      11 print(apple)
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-3-ce05055c122e> in print(d)
#       7
#       8 def print(d):
# ----> 9     print(f'Hi there! you printed {d}. Well done!')
#      10     return
#      11 print(apple)
#
# RecursionError: maximum recursion depth exceeded
